# %% [markdown]
# # **ClassWork on 2/7/2024 (Sentiment Analysis)**

# %% [markdown]
# ## **Import Pandas**

# %%
import pandas as pd # Importing pandas as pd

# %% [markdown]
# ## **Loading DataSet**

# %%
df=pd.read_csv("C:/Users/Mohan/Desktop/Text based Analysis/Arts_Crafts_and_sewing_5.csv") # File Path
df.sample(20)
# Out:
#         overall  verified      reviewerID        asin  \
# 454041        2      True   AK5NTRFQ7GMQK  B00902XQ6O
# 298467        5      True   A63IX65QDM6KT  B00DB90PB6
# 154188        5      True  A2JBHX7TSTKLS3  B000WE04KU
# 17267         5      True  A1A244G68REEJ6  B000BNLLHW
# 469708        5      True  A2K7X4258JRXW3  B00HNMMFWO
# 158601        5      True  A1Q139AIDBGZ8B  B001RBOY8U
# 400768        5      True  A1R18760FFPIWA  B01AK8G52S
# 425043        5      True  A3QMA0LSRAP5AC  B00114RC96
# 90085         4      True  A32BYNU0TPD9VQ  B000WWKE5W
# 110467        5      True   AQZRU8O1Y4DO5  B00114OTCE
# 299935        5      True  A3IMBPNQYEZUWC  B00DMXM34S
# 288005        5      True  A1271GA869M8WL  B00BRG5IK8
# 84852         5      True  A16GLLH55ILX2S  B0017KYE5Y
# 212141        3      True  A2RGQXJMIME0PO  B004ISA4ZQ
# 339024        5      True  A247RC20YZ7P35  B00KJ1SGGK
# 119665        5      True  A19R5LCSQUHDB0  B00161N5OU
# ...

# %% [markdown]
# ## **Installing Scikit-Learn**

# %%
#!pip install scikit-learn

# %% [markdown]
# ## **Getting the Bing Liu lexicon**

# %%
from sklearn import preprocessing # Importing Preprocessing
import nltk                       # Importing nltk
nltk.download('opinion_lexicon')
from nltk.corpus import opinion_lexicon # Importing oponion_Lexicon
from nltk.tokenize import word_tokenize # Imorting word_tokenize

print('Total number of words in opinion lexicon', len(opinion_lexicon.words()))
print('Examples of positive words in opinion lexicon',
      opinion_lexicon.positive()[:10])
print('Examples of negative words in opinion lexicon',
      opinion_lexicon.negative()[:10])
# Out:
# Total number of words in opinion lexicon 6789
# Examples of positive words in opinion lexicon ['a+', 'abound', 'abounds', 'abundance', 'abundant', 'accessable', 'accessible', 'acclaim', 'acclaimed', 'acclamation']
# Examples of negative words in opinion lexicon ['2-faced', '2-faces', 'abnormal', 'abolish', 'abominable', 'abominably', 'abominate', 'abomination', 'abort', 'aborted']
# [nltk_data] Downloading package opinion_lexicon to
# [nltk_data]     C:\Users\srima\AppData\Roaming\nltk_data...
# [nltk_data]   Package opinion_lexicon is already up-to-date!

# %% [markdown]
# ## **Creating the Dictionary**

# %%
nltk.download('punkt')
df.rename(columns={"reviewText": "text"}, inplace=True)
pos_score = 1
neg_score = -1
word_dict = {}
 
# Adding the positive words to the dictionary
for word in opinion_lexicon.positive():
        word_dict[word] = pos_score
      
# Adding the negative words to the dictionary
for word in opinion_lexicon.negative():
        word_dict[word] = neg_score
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\srima\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## **Math Function**

# %%
def bing_liu_score(text): 
    sentiment_score = 0
    bag_of_words = word_tokenize(text.lower())
    for word in bag_of_words:
        if word in word_dict:
            sentiment_score += word_dict[word]
    return sentiment_score

# %%
df['text'].fillna('no review', inplace=True)
df['Bing_Liu_Score'] = df['text'].apply(bing_liu_score)
# Out:
# C:\Users\srima\AppData\Local\Temp\ipykernel_53852\3064231398.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['text'].fillna('no review', inplace=True)

# %% [markdown]
# ## **Output Code**

# %%
df[['overall',"text", 'Bing_Liu_Score']].head(10) # OutPut Code
# Out:
#    overall                                               text  Bing_Liu_Score
# 0        4                Contains some interesting stitches.               1
# 1        5  I'm a fairly experienced knitter of the one-co...              22
# 2        4  Great book but the index is terrible. Had to w...               0
# 3        5  I purchased the Kindle edition which is incred...               4
# 4        5  Very well laid out and very easy to read.\n\nT...               5
# 5        5  Beginning her career as a freelance knitter, M...              15
# 6        5  This is a terrific stitch handbook (and I have...               9
# 7        4  The book needs to be coil bound. The content i...               1
# 8        5  I really am enjoying this book! I like the siz...              12
# 9        5  Just received this book and looked over it cov...               6

# %%
df.groupby('overall').agg({'Bing_Liu_Score':'mean'})
# Out:
#          Bing_Liu_Score
# overall
# 1             -0.255049
# 2              0.566098
# 3              1.158796
# 4              2.027999
# 5              2.129986
